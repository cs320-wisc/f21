# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
fig, ax = plt.subplots()
t = ax.text(0.5, 0.5, "TODO", size=72, va="center", ha="center")
def draw_frame(frame_num):
    #ax.cla()
    print("DEBUG", frame_num)
    #ax.text(0.5, 0.5, str(frame_num), size=72, va="center", ha="center")
    t.set_text(str(frame_num))

#draw_frame(0)

anim = FuncAnimation(fig, draw_frame, 10)
html = anim.to_html5_video()
html[:200]
plt.close()
t
# Out:
# DEBUG 0
# DEBUG 0
# DEBUG 1
# DEBUG 2
# DEBUG 3
# DEBUG 4
# DEBUG 5
# DEBUG 6
# DEBUG 7
# DEBUG 8
# DEBUG 9
# Text(0.5, 0.5, '9')

# %%
with open("out.html", "w") as f:
    f.write(html)

# %%
from IPython.core.display import HTML
HTML(html)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.core.display import HTML
from time import time

fig, ax = plt.subplots(figsize=(6,6))

circ = plt.Circle((0, 0), 0.1, facecolor="red", zorder=1)
ax.add_artist(circ)
rect = plt.Rectangle((0, 0.3), 1, 0.1, facecolor="black", zorder=2)
ax.add_artist(rect)

def draw_frame(frame_num):
    circ.center = (frame_num*0.1, 0.5)

anim = FuncAnimation(fig, draw_frame, frames=10, interval=250)
t0 = time()
html = anim.to_html5_video()
t1 = time()
print("Seconds to generate:", t1-t0)
#plt.close(fig)
HTML(html)
# Out:
# Seconds to generate: 0.5358808040618896
# <video width="432" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
